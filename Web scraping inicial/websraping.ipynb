# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import csv
from time import sleep
import pandas as pd
import random
import time

# %%
for i in range(5):
    print(f'doing something ... round{i+1}')
    sleep (3)
# Out:
# doing something ... round1
# doing something ... round2
# doing something ... round3
# doing something ... round4
# doing something ... round5

# %%
for i in range(5):
    print(f'doing something ... round{i+1}')
    delay = random.uniform(1,5)
    print(f'waiting{delay:.2f} seconds...')
    sleep(delay)
# Out:
# doing something ... round1
# waiting3.69 seconds...
# doing something ... round2
# waiting4.80 seconds...
# doing something ... round3
# waiting2.37 seconds...
# doing something ... round4
# waiting2.83 seconds...
# doing something ... round5
# waiting1.11 seconds...

# %%
for i in range (2,10):
    url = f"https://www.tudogostoso.com.br/receitas?page={i}"
    print(f'Fetching URL: {url}')
# Out:
# Fetching URL: https://www.tudogostoso.com.br/receitas?page=2
# Fetching URL: https://www.tudogostoso.com.br/receitas?page=3
# Fetching URL: https://www.tudogostoso.com.br/receitas?page=4
# Fetching URL: https://www.tudogostoso.com.br/receitas?page=5
# Fetching URL: https://www.tudogostoso.com.br/receitas?page=6
# Fetching URL: https://www.tudogostoso.com.br/receitas?page=7
# Fetching URL: https://www.tudogostoso.com.br/receitas?page=8
# Fetching URL: https://www.tudogostoso.com.br/receitas?page=9

# %%
page_to_scrape = requests.get("https://www.tudogostoso.com.br?page=2")
soup = BeautifulSoup(page_to_scrape.text,"html.parser")

titles = soup.find_all("span",attrs={"class":"card-title"})
ratings = soup.find_all("span",attrs={"class":"rating-votes"})
for t in titles:
    print(t.text)
driver.quit()
